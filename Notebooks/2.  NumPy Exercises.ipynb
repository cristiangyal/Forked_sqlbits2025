# %% [markdown]
# # 🧪 NumPy Practice Notebook
#
# This notebook is for you to practise working with NumPy arrays, indexing, broadcasting, and performance.
# Fill in the missing parts in each code cell where marked.
#
# **Topics Covered:**
# - Creating arrays
# - Indexing
# - Scalar, row, and column broadcasting
# - Performance comparison

# %% [markdown]
# ## 1️⃣ Create a 2D Array

# %%
import numpy as np

# TODO: Create a 3x3 array with numbers 1 to 9
matrix = 

print("📐 2D Array:\n", matrix)

# %% [markdown]
# ## 2️⃣ Indexing

# %%
# TODO: Print the first row of the matrix
# TODO: Print the value at row 2, column 3
# TODO: Print a 2x2 sub-matrix from the top-left corner

# %% [markdown]
# ## 3️⃣ Scalar Broadcasting

# %%
# TODO: Add 5 to every element
# TODO: Multiply each value by 3

# %% [markdown]
# ## 4️⃣ Row-wise Broadcasting

# %%
# TODO: Create a row vector [1, 0, -1]
# TODO: Add it to each row of the matrix

# %% [markdown]
# ## 5️⃣ Column-wise Broadcasting

# %%
# TODO: Create a column vector [10, 20, 30]
# HINT: use .reshape(3, 1)
# TODO: Add it to each column of the matrix

# %% [markdown]
# ## 6️⃣ Performance: Python List vs NumPy

# %%
import time

# TODO: Create a list of 1 million numbers and time a loop doubling them
# TODO: Convert to NumPy array and time the same operation
