# %% [markdown]
# # PySpark Practice Notebook
#
# Welcome to the PySpark learner notebook!

# %%
# 📥 Load sample data into a DataFrame
# Hint: use spark.read.option().csv()

# %%
# 👀 Preview the data
# Hint: use .show()

# %%
# 🧹 Task 1: Filter rows where column 'age' > 30
# Hint: use .filter()

# %%
# 🔄 Task 2: Select specific columns (e.g., name and age)
# Hint: use .select()

# %%
# 🧮 Task 3: Group by a column (e.g., department) and count
# Hint: use .groupBy().count()

# %%
# 🔗 Task 4: Join with another DataFrame
# Hint: use .join() on a key

# %%
# 💾 Task 5: Save the transformed DataFrame to parquet
# Hint: use .write.parquet()
