# %% [markdown]
# # 🌟 Intro to Python – Session 1 Recap
#
# Welcome to your first Python session! 🎉
# In this notebook, you’ll practise the key building blocks of Python using small and friendly examples.

# %% [markdown]
# ## 🔤 1. Hello, Python!
# ➡️ Type a simple print statement to say hello!

# %%
# TODO: Write a print statement
# Example: print("Hello, Python!")

print("Hello World")
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 3, Finished, Available, Finished)
# Hello World

# %% [markdown]
# ## 📋 2. Lists – Your First Python Collection
# ➡️ Create a list of your 3 favourite things.
# Then print the second item.

# %%
# TODO: Define a list
# Example: fruits = ["apple", "banana", "cherry"]
# fruits = []
# print(fruits)

favthings = ["marathon running", "dogs", "life"]
favthings[1]
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 5, Finished, Available, Finished)
# 'dogs'

# %% [markdown]
# ## 🗂️ 3. Dictionaries – Store Information with Keys
# ➡️ Create a dictionary for a dog with name, age, and breed.

# %%
# TODO: Define a dictionary
#Example: dog = {"name": "Sam", "age": 4, "breed": "Vizslador"}

dog = {"name": "Treacle", "age": "nomore", "breed": "Lab"}
print(dog)
print(dog["name"])
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 8, Finished, Available, Finished)
# {'name': 'Treacle', 'age': 'nomore', 'breed': 'Lab'}
# Treacle

# %% [markdown]
# ## 🤔 4. If Statement – Make Decisions
# ➡️ Write an if statement that prints "You’re awesome!" if a variable `mood` is `"happy"`.

# %%
# TODO: Add an if statement
# Example:
# mood = "happy"
# if mood == "happy":
#     print("You’re awesome!")

mood = "rainy"
if mood == "rainy":
    print("oh dear")
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 9, Finished, Available, Finished)
# oh dear

# %% [markdown]
# ## 🔄 5. If...Else – Do One Thing or Another
# ➡️ Write a program that prints a message depending on the mood

# %%
# TODO: Add an if...else statement

mood = "happy"

if mood == "rainy":
    print("oh dear")
elif mood == "happy":
    print("Yay")
else:
    print("yucky")
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 11, Finished, Available, Finished)
# Yay

# %% [markdown]
# ## 🧠 6. Functions – Reusable Code Blocks
# ➡️ Write a function called `greet` that takes a name and prints a greeting.

# %%
# TODO: Define and call a function
# Example:
# def greet(name):
#     print(f"Hello, {name}!")
name = "Sue"

def hello(name):
    '''
    this says hello
    '''
    print(f"Hello, {name}!" )

hello(name)
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 13, Finished, Available, Finished)
# Hello, Sue!

# %% [markdown]
# ## 📦 7. Tuples – Fixed Collections
# ➡️ Tuples are useful for grouping items that belong together and don’t need changing. Unlike lists, they are immutable.

# %%
# TODO: Create a tuple for a person with (name, interest, city)
# Example: runner = ("Sue", "marathon running", "Plymouth")

person = ("Sue", "marathon running", "Plymouth")
print(person[1])
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 15, Finished, Available, Finished)
# marathon running

# %% [markdown]
# ## 🙋 8. Asking for Help – Built-in Python Help
# ➡️ Use help() or ? to find out what a function does.

# %%
# TODO: Try asking for help on the 'print' function

help(print)  # You can also try: ........

help(tuple)
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 17, Finished, Available, Finished)
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.
#
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
# ...

# %% [markdown]
# ## 🧮 9. Built-in Functions – Python’s Handy Helpers
# ➡️ Python includes many built-in functions to do useful things quickly — no extra setup needed.

# %%
# TODO: Explore these built-in functions with name, age, and scores

name = "Alice"
age = 30
scores = [88, 92, 79]

print(f"Length of name: {len(name)}")               # len() is a function
print(f"Age as a string: {str(age)}")               # str() converts a number to string
print(f"Highest score: {max(scores)}")              # max() gets the maximum value
print(f"Lowest score: {min(scores)}")               # min() gets the minimum value
print(f"Average score: {sum(scores)/len(scores)}")  # sum() and len() used together
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 18, Finished, Available, Finished)
# Length of name: 5
# Age as a string: 30
# Highest score: 92
# Lowest score: 79
# Average score: 86.33333333333333

# %% [markdown]
# ## 📊 Sample Dataset – Let's Use Simple Data
# You’ll use a tiny DataFrame for fun analysis:
#
# | name   | age |
# |--------|-----|
# | Sam    | 4   |
# | Daisy  | 7   |
#
# Let's load it in below!

# %%
import pandas as pd

# Create a simple DataFrame
df = pd.DataFrame({
    "name": ["Sam", "Daisy"],
    "age": [4, 7]
})

# Display the table
df.shape
# Out:
# StatementMeta(, 010d6853-a473-424b-ba66-8902574d1fec, 20, Finished, Available, Finished)
# (2, 2)

# %% [markdown]
# ## ✅ Recap – What You Did
#
# - Printed your first message
# - Created and explored lists and dictionaries
# - Wrote conditional logic using `if` and `if...else`
# - Defined and used your first function
# - Worked with a basic dataset using pandas
#
# 🌈 Well done! You're on your way 💪
