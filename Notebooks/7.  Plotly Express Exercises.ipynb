# %% [markdown]
# ## 🚀 Quickstart with Plotly Express
#
# In this 10-minute exercise, you'll create beautiful and interactive charts using Plotly's built-in datasets.
#
# We'll focus on:
# - A line chart
# - A bar chart
# - A scatter plot
#
# All using just a few lines of code!

# %%
import plotly.express as px

# Load the built-in 'gapminder' dataset
# HINT: Filter for year 2007
# Out:
# StatementMeta(, , -1, SessionStarting, , SessionStarting)

# %%
# 🌍 Line Chart - Life Expectancy Over Time for One Country
# HINT: Use px.line(), filter gapminder for a single country
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)

# %%
# 📊 Bar Chart - Population by Continent (2007)
# HINT: Use px.bar() with x='continent' and y='pop'
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)

# %%
# 🎯 Scatter Plot - GDP vs Life Expectancy, Size by Population
# HINT: Use px.scatter() and include size='pop'
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)
