# %% [markdown]
# # ✅ HR Dataset – Answer Key
#
# This notebook provides worked answers to the learner exercises using the HR dataset.

# %% [markdown]
# ## 1️⃣ Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2️⃣ Load the HR Dataset

# %%
df = pd.read_csv("/lakehouse/default/Files/HR_file.csv", delimiter=',')
print("✅ Data loaded successfully")

# %% [markdown]
# ## 3️⃣ Check If DataFrame Is Empty

# %%
if not df.empty:
    print("✅ DataFrame is not empty")
else:
    print("⚠️ No data found")

# %% [markdown]
# ## 4️⃣ Explore the Columns and Shape

# %%
print("📋 Column names:", df.columns.tolist())
print("🔍 Shape of the dataset:", df.shape)

# %% [markdown]
# ## 5️⃣ Preview the Data

# %%
df.head()

# %% [markdown]
# ## 6️⃣ Check Column Data Types

# %%
df.dtypes
