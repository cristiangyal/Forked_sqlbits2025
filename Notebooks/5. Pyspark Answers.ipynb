# %% [markdown]
# # PySpark Answer Notebook
#
# Here are the solutions to the PySpark exercises.

# %%
df = spark.read.format("csv").option("header","true").load("Files/personality_dataset.csv")
display(df)
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 3, Finished, Available, Finished)

# %%
type(df)
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 4, Finished, Available, Finished)
# pyspark.sql.dataframe.DataFrame

# %%
df.show()
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 5, Finished, Available, Finished)
# +----------------+----------+-----------------------+-------------+-------------------------+-------------------+--------------+-----------+
# |Time_spent_Alone|Stage_fear|Social_event_attendance|Going_outside|Drained_after_socializing|Friends_circle_size|Post_frequency|Personality|
# +----------------+----------+-----------------------+-------------+-------------------------+-------------------+--------------+-----------+
# |             4.0|        No|                    4.0|          6.0|                       No|               13.0|           5.0|  Extrovert|
# |             9.0|       Yes|                    0.0|          0.0|                      Yes|                0.0|           3.0|  Introvert|
# |             9.0|       Yes|                    1.0|          2.0|                      Yes|                5.0|           2.0|  Introvert|
# ...

# %%
# 🧹 Task 1: Filter rows where column 'Drained_after_socializing' = Yes
# Hint: use .filter()
# Filter rows where Drained_after_socializing = Yes
filtered_df = df.filter(df["Drained_after_socializing"] == "Yes")

# Display results
filtered_df.show()
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 6, Finished, Available, Finished)
# +----------------+----------+-----------------------+-------------+-------------------------+-------------------+--------------+-----------+
# |Time_spent_Alone|Stage_fear|Social_event_attendance|Going_outside|Drained_after_socializing|Friends_circle_size|Post_frequency|Personality|
# +----------------+----------+-----------------------+-------------+-------------------------+-------------------+--------------+-----------+
# |             9.0|       Yes|                    0.0|          0.0|                      Yes|                0.0|           3.0|  Introvert|
# |             9.0|       Yes|                    1.0|          2.0|                      Yes|                5.0|           2.0|  Introvert|
# |            10.0|       Yes|                    1.0|          3.0|                      Yes|                0.0|           3.0|  Introvert|
# ...

# %%
# 🔄 Task 2: Select specific columns (e.g., Friends_circle_size and Post_frequency)
# Hint: use .select()
selected_df = df.select('Post_frequency', 'Friends_circle_size')
selected_df.show()
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 7, Finished, Available, Finished)
# +--------------+-------------------+
# |Post_frequency|Friends_circle_size|
# +--------------+-------------------+
# |           5.0|               13.0|
# |           3.0|                0.0|
# |           2.0|                5.0|
# |           8.0|               14.0|
# |           5.0|                8.0|
# |           6.0|                6.0|
# |           7.0|                7.0|
# |           8.0|                7.0|
# |           3.0|                0.0|
# |           8.0|               13.0|
# |           5.0|               15.0|
# |           0.0|                4.0|
# |          10.0|               14.0|
# |           7.0|               10.0|
# |           3.0|                1.0|
# |           8.0|                8.0|
# |           0.0|                0.0|
# |           4.0|               10.0|
# |           2.0|                4.0|
# |           5.0|               12.0|
# ...

# %%
# 🧮 Task 3: Group by a column (e.g., Personality) and count
# Hint: use .groupBy().count()
grouped_df = df.groupBy('Personality').count().show()
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 8, Finished, Available, Finished)
# +-----------+-----+
# |Personality|count|
# +-----------+-----+
# |  Extrovert| 1491|
# |  Introvert| 1409|
# +-----------+-----+

# %%
df.write.mode("overwrite").parquet("Files/test.parquet")
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 13, Finished, Available, Finished)

# %%
# Save as a managed Delta table in Lakehouse
df.write.mode("overwrite").saveAsTable("test")
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 16, Finished, Available, Finished)

# %%
df.toPandas().to_parquet('/lakehouse/default/Files/datafile.parquet')
# Out:
# StatementMeta(, e17f00ad-5493-42ab-b3e3-b50c5bb4b78f, 12, Finished, Available, Finished)
